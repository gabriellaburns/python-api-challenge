# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 633

# %%
#create new lists to store api data
city_name_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

# %%
#API calls
print("Beginning Data Retrieval ")
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="


# For each city name in cities list, do below things...
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 : nanortalik
# Processing Record 2 of Set 1 : daman
# Processing Record 3 of Set 1 : albany
# Processing Record 4 of Set 1 : ushuaia
# Processing Record 5 of Set 1 : salinopolis
# City not found. Skipping...
# Processing Record 6 of Set 1 : tasiilaq
# Processing Record 7 of Set 1 : port alfred
# City not found. Skipping...
# Processing Record 8 of Set 1 : gamba
# Processing Record 9 of Set 1 : half moon bay
# Processing Record 10 of Set 1 : richards bay
# Processing Record 11 of Set 1 : san patricio
# City not found. Skipping...
# Processing Record 12 of Set 1 : katsuura
# Processing Record 13 of Set 1 : busselton
# Processing Record 14 of Set 1 : grindavik
# Processing Record 15 of Set 1 : rikitea
# Processing Record 16 of Set 1 : hervey bay
# Processing Record 17 of Set 1 : punta arenas
# Processing Record 18 of Set 1 : tigil
# Processing Record 19 of Set 1 : narsaq
# Processing Record 20 of Set 1 : voi
# Processing Record 21 of Set 1 : hilo
# Processing Record 22 of Set 1 : lasa
# Processing Record 23 of Set 1 : beringovskiy
# Processing Record 24 of Set 1 : hobart
# Processing Record 25 of Set 1 : vaitape
# Processing Record 26 of Set 1 : torbay
# Processing Record 27 of Set 1 : qaanaaq
# Processing Record 28 of Set 1 : bethel
# Processing Record 29 of Set 1 : castro
# Processing Record 30 of Set 1 : port blair
# Processing Record 31 of Set 1 : yambio
# Processing Record 32 of Set 1 : touros
# Processing Record 33 of Set 1 : codrington
# Processing Record 34 of Set 1 : ancud
# Processing Record 35 of Set 1 : ribeira grande
# Processing Record 36 of Set 1 : severo-kurilsk
# Processing Record 37 of Set 1 : dingle
# Processing Record 38 of Set 1 : lakatoro
# Processing Record 39 of Set 1 : isangel
# City not found. Skipping...
# Processing Record 40 of Set 1 : mataura
# Processing Record 41 of Set 1 : pacific grove
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 1 : rafaela
# Processing Record 43 of Set 1 : yellowknife
# Processing Record 44 of Set 1 : menongue
# City not found. Skipping...
# Processing Record 45 of Set 1 : dikson
# Processing Record 46 of Set 1 : saint-philippe
# City not found. Skipping...
# Processing Record 47 of Set 1 : saldanha
# Processing Record 48 of Set 1 : sao joao da barra
# City not found. Skipping...
# Processing Record 49 of Set 1 : bredasdorp
# Processing Record 50 of Set 1 : jamestown
# Processing Record 0 of Set 2 : barrow
# Processing Record 1 of Set 2 : faanui
# Processing Record 2 of Set 2 : amparafaravola
# Processing Record 3 of Set 2 : hithadhoo
# Processing Record 4 of Set 2 : kamaishi
# Processing Record 5 of Set 2 : kununurra
# Processing Record 6 of Set 2 : cherskiy
# Processing Record 7 of Set 2 : talnakh
# Processing Record 8 of Set 2 : arraial do cabo
# Processing Record 9 of Set 2 : airai
# Processing Record 10 of Set 2 : kotli loharan
# Processing Record 11 of Set 2 : barzas
# Processing Record 12 of Set 2 : youkounkoun
# City not found. Skipping...
# Processing Record 13 of Set 2 : mar del plata
# Processing Record 14 of Set 2 : laguna
# Processing Record 15 of Set 2 : ngunguru
# Processing Record 16 of Set 2 : east london
# Processing Record 2 of Set 5 : svetlyy
# Processing Record 3 of Set 5 : shingu
# Processing Record 4 of Set 5 : iralaya
# Processing Record 5 of Set 5 : monrovia
# Processing Record 6 of Set 5 : najran
# Processing Record 7 of Set 5 : chaupal
# Processing Record 8 of Set 5 : mocuba
# Processing Record 9 of Set 5 : nouadhibou
# Processing Record 10 of Set 5 : tuktoyaktuk
# Processing Record 11 of Set 5 : cabo san lucas
# Processing Record 12 of Set 5 : sakakah
# Processing Record 13 of Set 5 : krasnoborsk
# Processing Record 14 of Set 5 : taganak
# Processing Record 15 of Set 5 : lagos
# City not found. Skipping...
# Processing Record 16 of Set 5 : aklavik
# Processing Record 17 of Set 5 : beyneu
# City not found. Skipping...
# Processing Record 18 of Set 5 : fortuna
# Processing Record 19 of Set 5 : yazd
# Processing Record 20 of Set 5 : mananjary
# Processing Record 21 of Set 5 : bengkulu
# Processing Record 22 of Set 5 : praia da vitoria
# Processing Record 23 of Set 5 : biltine
# City not found. Skipping...
# Processing Record 24 of Set 5 : lodja
# Processing Record 25 of Set 5 : jackson
# Processing Record 26 of Set 5 : abu kamal
# Processing Record 27 of Set 5 : tiksi
# Processing Record 28 of Set 5 : san rafael
# Processing Record 29 of Set 5 : georgetown
# Processing Record 30 of Set 5 : caarapo
# Processing Record 31 of Set 5 : rovaniemi
# Processing Record 32 of Set 5 : san cristobal
# Processing Record 33 of Set 5 : itaituba
# Processing Record 34 of Set 5 : gao
# City not found. Skipping...
# Processing Record 35 of Set 5 : dondo
# Processing Record 36 of Set 5 : vanavara
# Processing Record 37 of Set 5 : hofn
# Processing Record 38 of Set 5 : virginia beach
# Processing Record 39 of Set 5 : tuatapere
# Processing Record 40 of Set 5 : nurota
# Processing Record 41 of Set 5 : hermanus
# Processing Record 42 of Set 5 : severodvinsk
# Processing Record 43 of Set 5 : iqaluit
# Processing Record 44 of Set 5 : namibe
# Processing Record 45 of Set 5 : chuzhou
# Processing Record 46 of Set 5 : christchurch
# Processing Record 47 of Set 5 : saint pete beach
# Processing Record 48 of Set 5 : batagay-alyta
# Processing Record 49 of Set 5 : cap malheureux
# Processing Record 50 of Set 5 : hanmer springs
# City not found. Skipping...
# Processing Record 0 of Set 6 : aksarka
# Processing Record 1 of Set 6 : gornji milanovac
# Processing Record 2 of Set 6 : harper
# Processing Record 3 of Set 6 : motala
# Processing Record 4 of Set 6 : valparaiso
# Processing Record 5 of Set 6 : binzhou
# Processing Record 6 of Set 6 : campbell river
# Processing Record 7 of Set 6 : sinnamary
# Processing Record 8 of Set 6 : vestmannaeyjar
# Processing Record 9 of Set 6 : umm kaddadah
# Processing Record 10 of Set 6 : tamala
# Processing Record 11 of Set 6 : general roca
# City not found. Skipping...
# Processing Record 12 of Set 6 : lidkoping
# Processing Record 13 of Set 6 : evansville
# Processing Record 14 of Set 6 : prince rupert
# Processing Record 15 of Set 6 : algeciras
# Processing Record 16 of Set 6 : sabang
# Processing Record 17 of Set 6 : pangnirtung
# Processing Record 18 of Set 6 : luanda
# Processing Record 19 of Set 6 : lavrentiya
# Processing Record 20 of Set 6 : datong
# Processing Record 21 of Set 6 : antsohihy
# Processing Record 22 of Set 6 : zarcero
# Processing Record 23 of Set 6 : channel-port aux basques
# Processing Record 24 of Set 6 : esperance
# Processing Record 25 of Set 6 : spearfish
# Processing Record 26 of Set 6 : macusani
# Processing Record 27 of Set 6 : mustasaari
# Processing Record 28 of Set 6 : nikolskoye
# Processing Record 29 of Set 6 : leopold
# Processing Record 30 of Set 6 : ambulu
# Processing Record 31 of Set 6 : manokwari
# Processing Record 32 of Set 6 : puerto colombia
# Processing Record 33 of Set 6 : amguri
# Processing Record 34 of Set 6 : juneau
# Processing Record 35 of Set 6 : sirjan
# Processing Record 36 of Set 6 : fuerte
# Processing Record 37 of Set 6 : okato
# City not found. Skipping...
# Processing Record 38 of Set 6 : honiara
# City not found. Skipping...
# Processing Record 39 of Set 6 : kenai
# City not found. Skipping...
# Processing Record 40 of Set 6 : nzega
# Processing Record 41 of Set 6 : iguape
# Processing Record 42 of Set 6 : venado tuerto
# City not found. Skipping...
# Processing Record 43 of Set 6 : coihaique
# Processing Record 44 of Set 6 : berasia
# Processing Record 45 of Set 6 : karak
# Processing Record 46 of Set 6 : namatanai
# Processing Record 47 of Set 6 : puerto madryn
# Processing Record 48 of Set 6 : kampene
# Processing Record 49 of Set 6 : esso
# Processing Record 50 of Set 6 : plettenberg bay
# Processing Record 0 of Set 7 : rio branco
# Processing Record 1 of Set 7 : erenhot
# Processing Record 2 of Set 7 : bogorodskoye
# Processing Record 3 of Set 7 : kokkola
# Processing Record 4 of Set 7 : dunedin
# Processing Record 5 of Set 7 : vao
# Processing Record 6 of Set 7 : kichera
# Processing Record 7 of Set 7 : lebu
# Processing Record 8 of Set 7 : prince albert
# Processing Record 9 of Set 7 : rognan
# City not found. Skipping...
# Processing Record 10 of Set 7 : maner
# City not found. Skipping...
# Processing Record 11 of Set 7 : firozpur jhirka
# Processing Record 12 of Set 7 : svetlaya
# City not found. Skipping...
# Processing Record 13 of Set 7 : cozumel
# Processing Record 14 of Set 7 : kavaratti
# Processing Record 15 of Set 7 : geraldton
# Processing Record 16 of Set 7 : ierapetra
# Processing Record 17 of Set 7 : quelimane
# Processing Record 18 of Set 7 : muros
# Processing Record 19 of Set 7 : yulara
# Processing Record 20 of Set 7 : cidreira
# Processing Record 21 of Set 7 : podgorica
# Processing Record 22 of Set 7 : xichang
# Processing Record 23 of Set 7 : ostrovnoy
# Processing Record 24 of Set 7 : oktyabrskoye
# City not found. Skipping...
# Processing Record 25 of Set 7 : kalmunai
# Processing Record 26 of Set 7 : upernavik
# Processing Record 27 of Set 7 : kabare
# Processing Record 28 of Set 7 : makakilo city
# Processing Record 29 of Set 7 : ketchikan
# Processing Record 30 of Set 7 : czestochowa
# Processing Record 31 of Set 7 : micheweni
# Processing Record 32 of Set 7 : barra patuca
# Processing Record 33 of Set 7 : chimbote
# Processing Record 34 of Set 7 : sisimiut
# Processing Record 39 of Set 11 : newport
# Processing Record 40 of Set 11 : kayerkan
# Processing Record 41 of Set 11 : wetaskiwin
# Processing Record 42 of Set 11 : tateyama
# Processing Record 43 of Set 11 : bollnas
# Processing Record 44 of Set 11 : kastamonu
# Processing Record 45 of Set 11 : andenes
# Processing Record 46 of Set 11 : asfi
# Processing Record 47 of Set 11 : bairiki
# Processing Record 48 of Set 11 : catalina
# Processing Record 49 of Set 11 : port hedland
# Processing Record 50 of Set 11 : rehoboth
# Processing Record 0 of Set 12 : biak
# City not found. Skipping...
# Processing Record 1 of Set 12 : ihosy
# Processing Record 2 of Set 12 : shitanjing
# Processing Record 3 of Set 12 : wattegama
# Processing Record 4 of Set 12 : kovdor
# Processing Record 5 of Set 12 : champerico
# Processing Record 6 of Set 12 : chegdomyn
# Processing Record 7 of Set 12 : dangriga
# Processing Record 8 of Set 12 : krasnoselkup
# City not found. Skipping...
# Processing Record 9 of Set 12 : bonthe
# City not found. Skipping...
# Processing Record 10 of Set 12 : eureka
# Processing Record 11 of Set 12 : tawau
# Processing Record 12 of Set 12 : nongstoin
# Processing Record 13 of Set 12 : lieksa
# Processing Record 14 of Set 12 : taoudenni
# Processing Record 15 of Set 12 : bilibino
# City not found. Skipping...
# Processing Record 16 of Set 12 : antalaha
# Processing Record 17 of Set 12 : matamoros
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_df = pd.DataFrame({"City":city_name_list,
    "Cloudiness":cloudiness_list,
    "Country":country_list,
    "Date":date_list,
    "Humidity":humidity_list,
    "Lat":lat_list,
    "Lng":lng_list,
    "Temp":max_temp_list,
    "Wind Speed":wind_speed_list})

#export to csv
city_df.to_csv("output_data_file2.csv")

# %%
#check to see if there are any cities where humidity is greater than 100
#by sorting values in humidity column
city_df.sort_values(["Humidity"], axis = 0, ascending=False)
# Out:
#                   City  Cloudiness Country        Date  Humidity      Lat  \
# 303               Esso          62      RU  1647202703       100  55.9333
# 340        Mikhaylovka          69      RU  1647202715       100  50.0600
# 568      Krasnosel'kup          88      RU  1647202791       100  65.7000
# 543               Teya          84      RU  1647202784       100  60.3778
# 490       Novy Urengoy         100      RU  1647202559       100  66.0833
# ..                 ...         ...     ...         ...       ...      ...
# 188              Bakel           4      SN  1647202667         8  14.9050
# 521  Estación Coahuila           2      MX  1647202778         8  32.1939
# 129           Tessalit           0      ML  1647202649         8  20.1986
# 541            Cayenne         100      GF  1647202783         1   4.9333
# 359             Jining         100      CN  1647202649         1  35.4050
#
#           Lng   Temp  Wind Speed
# 303  158.7000   3.81        4.21
# 340   43.2379   1.78        5.06
# 568   82.4667  -9.76        7.52
# 543   92.6267 -22.76        1.03
# 490   76.6333 -12.26        4.99
# ..        ...    ...         ...
# 188  -12.4568  90.12        7.38
# 521 -115.0017  82.22        6.91
# 129    1.0114  79.07        8.01
# 541  -52.3333  75.24        4.61
# 359  116.5814  57.00        7.11
#
# [578 rows x 9 columns]

# %%
plt.scatter(city_df['Lat'],city_df['Temp'],alpha=0.75,edgecolors='black')
plt.title(f"Latitude vs Temperature ({time.strftime('%m/%d/%y')})")
plt.xlabel('Latitude') 
plt.ylabel('Temperature (F)')
plt.xlim(min(city_df['Lat'])-20,max(city_df['Lat'])+20)
plt.ylim(min(city_df['Temp'])-20,max(city_df['Temp'])+20)
plt.grid()
plt.savefig("lat_vs_temp.png")

# %% [markdown]
# The above figure demonstrates two interesting relationships.
# 1. As latitude in the Northern hemisphere increases, temperatures drop.
# 2. Temperature also drops as latitude increases in the Southern hemisphere, but the decrease is not as steep as it is in the Northern hemisphere. I believe this can be explained by the distribution of the world population by lattitude; there are fewer people in the southern hemisphere, so therefore there will be fewer cities to pull data from. The website below illustrates this point, and I believe the distribution of cities in the randomly generated dataset I'm using also proves this point (I created dataframes for each hemisphere below)
#
# https://www.datagraver.com/case/world-population-distribution-by-latitude-and-longitude-2020

# %%
s_hemisphere = city_df[city_df["Lat"]<0]
s_hemisphere
# Out:
#              City  Cloudiness Country        Date  Humidity      Lat  \
# 3         Ushuaia          40      AR  1647202378        65 -54.8000
# 4     Salinópolis         100      BR  1647202608        88  -0.6136
# 6     Port Alfred         100      ZA  1647202608        91 -33.5906
# 7           Gamba         100      GA  1647202609        87  -2.6500
# 9    Richards Bay           0      ZA  1647202610        81 -28.7830
# ..            ...         ...     ...         ...       ...      ...
# 558  Port Hedland           0      AU  1647202788        94 -20.3167
# 559      Rehoboth         100      NA  1647202789        71 -23.3167
# 560          Biak          60      ID  1647202789        84  -0.9131
# 561         Ihosy         100      MG  1647202789        91 -22.4000
# 576      Antalaha         100      MG  1647202793        83 -14.9003
#
#           Lng   Temp  Wind Speed
# 3    -68.3000  44.26       39.12
# 4    -47.3561  78.53        8.50
# 6     26.8910  68.11       10.85
# 7     10.0000  77.63        5.77
# 9     32.0377  77.47       12.37
# ..        ...    ...         ...
# 558  118.5667  80.65        0.00
# 559   17.0833  67.24        7.54
# 560  122.8766  75.81        3.78
# 561   46.1167  67.35       10.04
# 576   50.2788  74.25        5.46
#
# [195 rows x 9 columns]

# %%
n_hemisphere = city_df[city_df["Lat"]>0]
n_hemisphere
# Out:
#               City  Cloudiness Country        Date  Humidity      Lat  \
# 0       Nanortalik         100      GL  1647202607        67  60.1432
# 1            Daman           0      IN  1647202607        37  20.4167
# 2           Albany         100      US  1647202559        32  42.6001
# 5         Tasiilaq         100      GL  1647202608        80  65.6145
# 8    Half Moon Bay          40      US  1647202609        62  37.4636
# ..             ...         ...     ...         ...       ...      ...
# 572      Nongstoin           3      IN  1647202792        36  25.5167
# 573         Lieksa         100      FI  1647202592        96  63.3167
# 574      Taoudenni           0      ML  1647202793         9  22.6783
# 575       Bilibino         100      RU  1647202793        95  68.0546
# 577      Matamoros           0      MX  1647202794        17  25.5333
#
#           Lng   Temp  Wind Speed
# 0    -45.2371  28.29       45.72
# 1     72.8500  80.24        4.27
# 2    -73.9662  34.66        1.01
# 5    -37.6368  30.36       20.29
# 8   -122.4286  68.05        9.22
# ..        ...    ...         ...
# 572   91.2667  59.11        5.75
# 573   30.0167  28.92        0.76
# 574   -3.9836  78.91        3.18
# 575  166.4372 -16.20        3.27
# 577 -103.2500  71.71        9.22
#
# [383 rows x 9 columns]

# %%
plt.scatter(city_df['Lat'],city_df['Humidity'],alpha=0.75,edgecolors='black')
plt.title(f"Latitude vs Humidity ({time.strftime('%m/%d/%y')})")
plt.xlabel('Latitude') 
plt.ylabel('Humidity (%)')
plt.xlim(min(city_df['Lat'])-20,max(city_df['Lat'])+20)
plt.ylim(min(city_df['Humidity'])-20,max(city_df['Humidity'])+20)
plt.grid()
plt.savefig("lat_vs_humidity.png")

# %%
plt.scatter(city_df['Lat'],city_df['Cloudiness'],alpha=0.75,edgecolors='black')
plt.title(f"Latitude vs Cloudiness ({time.strftime('%m/%d/%y')})")
plt.xlabel('Latitude') 
plt.ylabel('Cloudiness')
plt.xlim(min(city_df['Lat'])-20,max(city_df['Lat'])+20)
plt.ylim(min(city_df['Cloudiness'])-20,max(city_df['Cloudiness'])+20)
plt.grid()
plt.savefig("lat_vs_cloudiness.png")

# %%
plt.scatter(city_df['Lat'],city_df['Wind Speed'],alpha=0.75,edgecolors='black')
plt.title(f"Latitude vs Wind Speed ({time.strftime('%m/%d/%y')})")
plt.xlabel('Latitude') 
plt.ylabel('Wind Speed')
plt.xlim(min(city_df['Lat'])-20,max(city_df['Lat'])+20)
plt.ylim(min(city_df['Wind Speed'])-20,max(city_df['Wind Speed'])+20)
plt.grid()
plt.savefig("lat_vs_wind.png")

# %%
north = city_df.loc[city_df["Lat"] >= 0]
south = city_df.loc[city_df["Lat"] < 0]

x_values = north['Lat']
y_values = north['Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,10),fontsize=15,color="red")
plt.title("Temp vs. Latitude in the Northern Hemisphere")
plt.ylabel('Max Temperatures')
plt.xlabel('Latitudes')
plt.show()

# %%
y_values = south['Temp']
x_values = south['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-35,50),fontsize=15,color="red")
plt.title("Temp vs. Latitude in the Southern Hemisphere")
plt.ylabel('Max Temperatures')
plt.xlabel('Latitudes')
plt.show()

# %% [markdown]
# As I predicted in my analysis of the Temperature (F) vs. Latitude graph, the temperature increases as latititude approaches the equator in both hemispheres. However, the relationship between latitude and temperature is stronger in the northern hemisphere.

# %%
y_values = north['Humidity']
x_values = north['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.title("Humidity vs. Latitude in the Northern Hemisphere")
plt.ylabel('Humidity (%)')
plt.xlabel('Latitudes')
plt.show()

# %%
y_values = south['Humidity']
x_values = south['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,40),fontsize=15,color="red")
plt.title("Humidity vs. Latitude in the Southern Hemisphere")
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.show()

# %% [markdown]
# There is a small positive correlation between humidity and latitude the southern and northern hemisphere (cities near the equator are more humid than those further away), but it is not very strong. In contrast, it appears that cities in higher latitudes in the northern hemisphere are associated with higher humidity.

# %%
y_values = north['Cloudiness']
x_values = north['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(35,45),fontsize=15,color="red")
plt.title("Cloudiness vs. Latitude in the Northern Hemisphere")
plt.ylabel('Cloudiness')
plt.xlabel('Latitude')
plt.show()

# %%
y_values = south['Cloudiness']
x_values = south['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55, 54),fontsize=15,color="red")
plt.title("Cloudiness vs. Latitude in the Southern Hemisphere")
plt.ylabel('Cloudiness')
plt.xlabel('Latitude')
plt.show()

# %%
y_values = north['Wind Speed']
x_values = north['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,30),fontsize=15,color="red")
plt.title("Wind Speed vs. Latitude in the Northern Hemisphere")
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.show()

# %%
y_values = south['Wind Speed']
x_values = south['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,30),fontsize=15,color="red")
plt.title("Wind Speed vs. Latitude in the Southern Hemisphere")
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.show()

# %% [markdown]
# Latitude has an almost negligable relationship to wind speed in both hemispheres, with the Southern hemisphere showing a slight negative relationship between latitude and wind speed.
